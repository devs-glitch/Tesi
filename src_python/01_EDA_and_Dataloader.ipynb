# %% [markdown]
# 4 celle logiche per validare la tua Milestone (M1):
#
# - **Cella di Import:** Importa PyTorch, Matplotlib e il tuo script personalizzato `from data_loader import get_dataloaders, poisson_encode`.
# - **Cella di Inizializzazione:** Istanzia i dataloader definendo il `batch_size`. Esegui l'iterazione su un singolo batch di dati.
# - **Cella di Plot Spaziale (EDA):** Usa Matplotlib per stampare una griglia 2x2 contenente un'immagine per ciascuna delle 4 classi scelte (Blip, Whistle, Power Line, Scattered Light), stampando i loro tensori analogici per verificare che le etichette combacino.
# - **Cella di Plot Temporale (M1 Target):** Seleziona un singolo sample dal batch, passalo alla tua funzione `poisson_encode` e genera un raster plot. Questo plot mostrerà visivamente come i pixel statici dell'immagine si sono trasformati in spike distribuiti nel tempo, dimostrando che il tuo input è pronto per una Rete Neurale Spiking. Salva questa immagine in `results/plots/`.
